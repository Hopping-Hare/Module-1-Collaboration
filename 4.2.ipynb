# %%
small = True
green = False

if cherry:
    small = True
    green = False
elif pea:
    small = True
    green = True
elif watermelon:
    small = False 
    green = True
elif pumpkin:
    small = False
    green = False
